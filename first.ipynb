# %%
print("Hi")
# Out:
# Running cells with 'myEnvironment (Python 3.11.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/GITHUB/Machine-Learning-/myEnvironment/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
